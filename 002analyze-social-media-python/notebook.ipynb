# %%
import pandas as pd
import numpy as np
import random
from matplotlib import pyplot as plt
import seaborn as sns

# Define the list of categories
categories = ['Food', 'Travel', 'Fashion', 'Fitness', 'Music', 'Culture', 'Family', 'Health']

# Number of entries (n)
n = 500

# Generate random data
data = {
    'Date': pd.date_range('2023-01-01', periods=n),
    'Category': [random.choice(categories) for _ in range(n)],
    'Likes': np.random.randint(0, 10000, size=n)
}

# Create a DataFrame
df = pd.DataFrame(data)

# Print the first few rows of the DataFrame
print(df.head(10))
# Out:
#         Date Category  Likes
# 0 2023-01-01   Travel   4703
# 1 2023-01-02  Fashion   6257
# 2 2023-01-03  Fitness   3592
# 3 2023-01-04   Travel   4769
# 4 2023-01-05   Family   6300
# 5 2023-01-06   Health   6524
# 6 2023-01-07  Culture   3744
# 7 2023-01-08    Music   6140
# 8 2023-01-09  Fashion   7128
# 9 2023-01-10   Family   1788

# %%
plt.figure(figsize=(10, 6))
sns.displot(df['Likes'], kde=False)
plt.xlabel('Number of Likes')
plt.ylabel('Frequency')
plt.title('Distribution of Likes')
plt.show()
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:64: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Category', y='Likes', data=df)
plt.xlabel('Category')
plt.ylabel('Number of Likes')
plt.title('Likes Distribution Across Categories')
plt.xticks(rotation=45)
plt.show()
